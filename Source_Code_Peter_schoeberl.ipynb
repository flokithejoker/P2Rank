# %% [markdown]
# # Bioinformatics - Binging Pocket Prediction
#
# ## Peter Schöberl (K12325049)

# %% [markdown]
# This Notebook will outline my approach to solving the challenge for Bioninformatics 2024.

# %% [markdown]
# # Approach
#
# 1. **Data Analysis**
#
#    First I downloaded the given files for our challenge. I installed PyMol for visualising the data to get a feeling of how to look at proteins and their corresponding 3D shapes and binding pockets.
#
# 2. **Data Preparation**
#
#    For the first trial I decided to try the prediction with P2Rank since it is a well established method which doesn't require training nor preprocessing for running first evaluations.
#
# 3. **Model Training**
#
#    If the accuracy is not "good enough" I will further train P2Rank specifically on our training data to then evaluate how the accuracy (in this case measured by the Jaccard index) improves.
#
# 4. **Model Evaluation**
#
#    For model evaluation I will first run a test trial on 100 AA from our given training set where we also have the corresponding labeled binding pockets. With this I hope to validate my approach.
#
# 5. **Postprocessing**
#
#    To export the predictions as required (see sample_submission) I had to extract the residuals which were assigned to binding pockets from the corresponding csv files.

# %% [markdown]
# # P2Rank Installation
#
# 1. **Cloning the repository from GIT**
#
# git clone https://github.com/rdk/p2rank.git && cd p2rank
#
# 2. **Building the project**
#
# ./make.sh
#
# 3. **Running the project on its test files**
#
# ./unit-tests.sh
#
# 4. **Notes for later to set in training mode**
#
# distro/prank       # Standard mode for production
#
# ./prank.sh         # Development/training mode

# %% [markdown]
# # Testing P2Rank on a single file
#
# For a first trial I wrote a function to simply make predictions for a single pdb file.
# Such that I can be sure the program works as expected.

# %%
import os
import subprocess
# SINGLE PDB FILE

# Running P2Rank works without preprocessing and without training
# So thats what we will do here as a first try

def run_p2rank_on_file(p2rank_dir, pdb_file, output_dir):

    # Ensure the output directory exists
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # We construct the command that will be called
    prank_executable = os.path.join(p2rank_dir, 'distro', 'prank')
    command = [prank_executable, 'predict', '-f', pdb_file, '-o', output_dir]

    # Run the P2Rank command
    result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    # Print the output
    print("P2Rank Output:\n", result.stdout.decode())
    #print("P2Rank Errors:\n", result.stderr.decode())

# Example usage
# p2rank_directory = "/Users/peter/p2rank"
# pdb_file_path = "/Users/peter/VS_Studio/Bioninformatics/test_0/0_protein.pdb"
# output_directory = "/Users/peter/VS_Studio/Bioninformatics/Outputs"

#run_p2rank_on_file(p2rank_directory, pdb_file_path, output_directory)

# %% [markdown]
# # Running P2Rank on a directory
#
# The program seems to work fine so I will implement a function that runs predictions over all pdb files that are listed in a directory. The directory path for the output can be specified as input for the function.

# %%
# Now since the first test work we will loop over all pdb files in our test directory
import os
import subprocess

def run_p2rank_on_directory(p2rank_dir, pdb_directory, output_dir):

    # Ensure the output directory exists
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # we collect all pdb files as a list
    pdb_files = [f for f in os.listdir(pdb_directory) if f.endswith('.pdb')]

    # then we loop over every single pdb files
    for pdb_file in pdb_files:
        # get the path to the pdb file
        pdb_path = os.path.join(pdb_directory, pdb_file)
        
        # construct the P2Rank command
        prank_executable = os.path.join(p2rank_dir, 'distro', 'prank')
        command = [prank_executable, 'predict', '-f', pdb_path, '-o', output_dir]

        # Run the P2Rank command
        result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE)

        # Print the output
        print(f"P2Rank Output for {pdb_file}:\n", result.stdout.decode())
        #print(f"P2Rank Errors for {pdb_file}:\n", result.stderr.decode())

# Example usage
# p2rank_directory = "/Users/peter/p2rank"
# pdb_files_directory = "/Users/peter/VS_Studio/Bioninformatics/test_0"
# output_directory = "/Users/peter/VS_Studio/Bioninformatics/Outputs"

# run_p2rank_on_directory(p2rank_directory, pdb_files_directory, output_directory)

# %% [markdown]
# # Extracting predictions
# For each structure file in the dataset P2Rank produces several output files. Therefore we need a script which pulls out the relevant information for our submission and collects it in the corresponding format as required (see sample_submission). The key here is to realize that our prediction corresponds to the amino acids which where attributed to a binding pocket by P2Rank.

# %%
# We collect our results from the _residues.csv files
# residue_label - This column contains the labels of the residues.
# pocket        - This column indicates which pocket each residue is part of. If the residue is part of a binding pocket, this column will have a non-zero value.

import os
import pandas as pd

def collect_binding_residues(output_dir, submission_file):
    submission_data = []

    for item in os.listdir(output_dir):
        # we only look at files that end with _residues.csv
        if item.endswith('_residues.csv'):
            # we get the id by simply removing the rest of the file name
            pdb_id = item.replace('_protein.pdb_residues.csv', '')
            # then we collect the file path to extract the predicitons
            residues_file_path = os.path.join(output_dir, item)
            df = pd.read_csv(residues_file_path)
            
            # I had to debug some key error because of a missing blank space -.-
            #print(df)
            #print(f"Columns in {residues_file_path}: {df.columns.tolist()}")

            # for proper evaluation we require that predictions are stripped properly
            df.columns = df.columns.str.strip()

            # basically if the residue is part of a binding pocket we add it to our predictions
            #binding_residues = df[df['pocket'] > 0]['residue_label'].tolist()
            binding_residues = df[df['pocket'] > 0].apply(lambda row: f"{row['chain']}_{row['residue_label']}", axis=1).tolist()
            prediction = ' '.join(binding_residues)
            submission_data.append({'id': pdb_id, 'prediction': prediction})

            # now we convert our submission_data to a csv file and save it with the inputted path
            df_submission = pd.DataFrame(submission_data)
            df_submission['prediction'] = df_submission['prediction'].astype(str) # ensures str which is necessary for evaluation
            # Sort by 'id' column
            # for this we need to convert the ids to integers
            df_submission['id'] = pd.to_numeric(df_submission['id'], errors='coerce')
            df_submission.sort_values(by='id', inplace=True)
            df_submission['id'] = df_submission['id'].astype(str) # reconvert part of debugging
            df_submission.to_csv(submission_file, index=False)

# submission_file = "/Users/peter/VS_Studio/Bioninformatics/traintestcsv.csv"
# output_dir = "/Users/peter/VS_Studio/Bioninformatics/Outputs"
# submission_data = collect_binding_residues(output_dir, submission_file)

# %% [markdown]
# # Validating the approach
#
# To validate my approach I implemented a function to calculate the jaccard index between to sets. Then I made prediction using P2Rank on the first 100 AA from our training set and compared them to the actual binding residues as stated in the train.csv file. Then row wise I compute the jaccard index and finally take the average jaccard index over all 100 rows as an indicator of how well P2Rank worked on this validation set.

# %%
# Since I did this without further training or preprocessing I wanted to get some feeling for the accuracy
# I applied P2Rank on 100 pdb files to calculate the Jaccard Index such that I could estimate my current accuracy


def calculate_jaccard_index(set1, set2):
    """
    Calculate the Jaccard index between two sets.
    """

    intersection = set1.intersection(set2)
    union = set1.union(set2)

    jaccard_index = len(intersection) / len(union)

    return jaccard_index

################################################################################################################################################


def evaluate_predictions_test(predictions_file, actual_file):
    actual_df = pd.read_csv(actual_file).iloc[:100]  # Extract rows 0-99
    predicted_df = pd.read_csv(predictions_file).iloc[:100]  # Extract rows 0-99

    jaccard_indices = []

    # Iterate over each row to calculate the Jaccard index
    for i in range(len(actual_df)):
        actual_residues = set(actual_df.iloc[i, 1].split())
        #print(actual_residues)
        #predicted_residues = set(predicted_df.iloc[i, 1].split())
        #print(predicted_residues)

        # i need to handle the case where predictions are empty thus being handled as float
        predicted_residues_str = predicted_df.iloc[i, 1]
        if pd.isna(predicted_residues_str):
            predicted_residues_str = ''
        predicted_residues = set(predicted_residues_str.split())
        jaccard_index = calculate_jaccard_index(actual_residues, predicted_residues)
        jaccard_indices.append(jaccard_index)

    # Compute the average Jaccard index
    average_jaccard = sum(jaccard_indices) / len(jaccard_indices) if jaccard_indices else 0
    return average_jaccard

# Example usage
# submission_file_path = "/Users/peter/VS_Studio/Bioninformatics/traintestcsv.csv"
# train_file_path = "/Users/peter/VS_Studio/Bioninformatics/train.csv"

# average_jaccard_index = evaluate_predictions_test(submission_file_path, train_file_path)
# print(f"Average Jaccard Index: {average_jaccard_index}")

######## RESULT ########
# Average Jaccard Index: 0.2572362310380812
# This would already be graded with a B which is fine by me so LETS GO

# %% [markdown]
# # Running P2Rank on our test dataset
#
# The results from our validation set were promissing, so I decided to apply P2Rank on the whole test set to upload my first submission. We follow these steps:
#
# 1. **run_p2rank_on_directory**
#
# This function will call the P2Rank command for every pdb file in our test directory
#
# 2. **collect_binding_residues**
#
# Then we will create a submission file from the outputs using the function we have earlier written to extract our predictions. The returned csv file corresponds to the format required for the upload on the challenge server
#
# 3. **model evaluation**
#
# We will upload our first submission to the server and evaluate our score :-)

# %%
# Run P2Rank on test directory
p2rank_directory = "/Users/peter/p2rank"
pdb_files_directory = "/Users/peter/VS_Studio/Bioninformatics/test"
output_directory = "/Users/peter/VS_Studio/Bioninformatics/Outputs"

run_p2rank_on_directory(p2rank_directory, pdb_files_directory, output_directory)


# Create submission file from the outputs
submission_file = "/Users/peter/VS_Studio/Bioninformatics/Submission.csv"
output_dir = "/Users/peter/VS_Studio/Bioninformatics/Outputs"

submission_data = collect_binding_residues(output_dir, submission_file)
# Out:
# P2Rank Output for 2940_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2940_protein.pdb]
# processing [2940_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 5.394 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 5.869 seconds.
#
# P2Rank Output for 1345_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1345_protein.pdb]
# processing [1345_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.547 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.056 seconds.
#
# P2Rank Output for 69_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [69_protein.pdb]
# processing [69_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.414 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.932 seconds.
#
# P2Rank Output for 1615_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1615_protein.pdb]
# processing [1615_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.642 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.143 seconds.
#
# P2Rank Output for 2566_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2566_protein.pdb]
# processing [2566_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.143 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.679 seconds.
#
# P2Rank Output for 1093_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1093_protein.pdb]
# processing [1093_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.576 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.035 seconds.
#
# P2Rank Output for 2036_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2036_protein.pdb]
# processing [2036_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.028 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.535 seconds.
#
# P2Rank Output for 885_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [885_protein.pdb]
# processing [885_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.694 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.208 seconds.
#
# P2Rank Output for 225_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [225_protein.pdb]
# processing [225_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.656 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.158 seconds.
#
# P2Rank Output for 775_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [775_protein.pdb]
# processing [775_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.793 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.298 seconds.
#
# P2Rank Output for 788_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [788_protein.pdb]
# processing [788_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.801 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.314 seconds.
#
# P2Rank Output for 2154_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2154_protein.pdb]
# processing [2154_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.565 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.060 seconds.
#
# P2Rank Output for 878_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [878_protein.pdb]
# processing [878_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.201 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.719 seconds.
#
# P2Rank Output for 2404_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2404_protein.pdb]
# processing [2404_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.446 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.954 seconds.
#
# P2Rank Output for 617_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [617_protein.pdb]
# processing [617_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.036 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.496 seconds.
#
# P2Rank Output for 347_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [347_protein.pdb]
# processing [347_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.128 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.623 seconds.
#
# P2Rank Output for 94_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [94_protein.pdb]
# processing [94_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.387 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.880 seconds.
#
# P2Rank Output for 1918_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1918_protein.pdb]
# processing [1918_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.283 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.801 seconds.
#
# P2Rank Output for 1777_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1777_protein.pdb]
# processing [1777_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.255 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.738 seconds.
#
# P2Rank Output for 2282_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2282_protein.pdb]
# processing [2282_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.142 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.671 seconds.
#
# P2Rank Output for 1227_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1227_protein.pdb]
# processing [1227_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.295 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.800 seconds.
#
# P2Rank Output for 2822_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2822_protein.pdb]
# processing [2822_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.350 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.859 seconds.
#
# P2Rank Output for 1887_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1887_protein.pdb]
# processing [1887_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.462 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.973 seconds.
#
# P2Rank Output for 183_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [183_protein.pdb]
# processing [183_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.360 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.848 seconds.
#
# P2Rank Output for 1335_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1335_protein.pdb]
# processing [1335_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.162 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.670 seconds.
#
# P2Rank Output for 2390_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2390_protein.pdb]
# processing [2390_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.237 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.754 seconds.
#
# P2Rank Output for 1665_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1665_protein.pdb]
# processing [1665_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.423 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.934 seconds.
#
# P2Rank Output for 19_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [19_protein.pdb]
# processing [19_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.640 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.142 seconds.
#
# P2Rank Output for 1995_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1995_protein.pdb]
# processing [1995_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.424 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.934 seconds.
#
# P2Rank Output for 2930_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2930_protein.pdb]
# processing [2930_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.717 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.188 seconds.
#
# P2Rank Output for 2516_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2516_protein.pdb]
# processing [2516_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.800 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.312 seconds.
#
# P2Rank Output for 2046_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2046_protein.pdb]
# processing [2046_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.983 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.504 seconds.
#
# P2Rank Output for 255_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [255_protein.pdb]
# processing [255_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.107 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.633 seconds.
#
# P2Rank Output for 705_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [705_protein.pdb]
# processing [705_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.485 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.994 seconds.
#
# P2Rank Output for 2489_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2489_protein.pdb]
# processing [2489_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.623 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.106 seconds.
#
# P2Rank Output for 2124_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2124_protein.pdb]
# processing [2124_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.227 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.741 seconds.
#
# P2Rank Output for 1181_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1181_protein.pdb]
# processing [1181_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.238 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.712 seconds.
#
# P2Rank Output for 2474_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2474_protein.pdb]
# processing [2474_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.555 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.036 seconds.
#
# P2Rank Output for 808_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [808_protein.pdb]
# processing [808_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.141 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.667 seconds.
#
# P2Rank Output for 997_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [997_protein.pdb]
# processing [997_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.433 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.890 seconds.
#
# P2Rank Output for 667_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [667_protein.pdb]
# processing [667_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.746 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.260 seconds.
#
# P2Rank Output for 337_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [337_protein.pdb]
# processing [337_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.355 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.852 seconds.
#
# P2Rank Output for 1968_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1968_protein.pdb]
# processing [1968_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.637 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 5.169 seconds.
#
# P2Rank Output for 1698_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1698_protein.pdb]
# processing [1698_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.034 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.546 seconds.
#
# P2Rank Output for 2852_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2852_protein.pdb]
# processing [2852_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.700 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.224 seconds.
#
# P2Rank Output for 1707_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1707_protein.pdb]
# processing [1707_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.375 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.859 seconds.
#
# P2Rank Output for 1257_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1257_protein.pdb]
# processing [1257_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.396 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.928 seconds.
#
# P2Rank Output for 2333_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2333_protein.pdb]
# processing [2333_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.204 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.662 seconds.
#
# P2Rank Output for 1396_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1396_protein.pdb]
# processing [1396_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.860 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.350 seconds.
#
# P2Rank Output for 2663_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2663_protein.pdb]
# processing [2663_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.132 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.655 seconds.
#
# P2Rank Output for 2993_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2993_protein.pdb]
# processing [2993_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.543 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.991 seconds.
#
# P2Rank Output for 1936_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1936_protein.pdb]
# processing [1936_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.059 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.594 seconds.
#
# P2Rank Output for 1209_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1209_protein.pdb]
# processing [1209_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.221 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.766 seconds.
#
# P2Rank Output for 1759_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1759_protein.pdb]
# processing [1759_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.131 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.633 seconds.
#
# P2Rank Output for 470_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [470_protein.pdb]
# processing [470_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.688 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.235 seconds.
#
# P2Rank Output for 120_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [120_protein.pdb]
# processing [120_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.282 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.801 seconds.
#
# P2Rank Output for 856_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [856_protein.pdb]
# processing [856_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.325 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.855 seconds.
#
# P2Rank Output for 369_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [369_protein.pdb]
# processing [369_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.523 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.055 seconds.
#
# P2Rank Output for 639_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [639_protein.pdb]
# processing [639_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.873 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.400 seconds.
#
# P2Rank Output for 1510_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1510_protein.pdb]
# processing [1510_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.463 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.012 seconds.
#
# P2Rank Output for 1040_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1040_protein.pdb]
# processing [1040_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 5.023 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 5.490 seconds.
#
# P2Rank Output for 2018_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2018_protein.pdb]
# processing [2018_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.426 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.918 seconds.
#
# P2Rank Output for 934_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [934_protein.pdb]
# processing [934_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.275 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.787 seconds.
#
# P2Rank Output for 2548_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2548_protein.pdb]
# processing [2548_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.102 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.641 seconds.
#
# P2Rank Output for 394_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [394_protein.pdb]
# processing [394_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.473 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.996 seconds.
#
# P2Rank Output for 1122_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1122_protein.pdb]
# processing [1122_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.242 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.777 seconds.
#
# P2Rank Output for 2187_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2187_protein.pdb]
# processing [2187_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.396 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.932 seconds.
#
# P2Rank Output for 1472_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1472_protein.pdb]
# processing [1472_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.540 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.013 seconds.
#
# P2Rank Output for 1854_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1854_protein.pdb]
# processing [1854_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.426 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.973 seconds.
#
# P2Rank Output for 2701_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2701_protein.pdb]
# processing [2701_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.586 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.118 seconds.
#
# P2Rank Output for 2251_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2251_protein.pdb]
# processing [2251_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.525 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.071 seconds.
#
# P2Rank Output for 512_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [512_protein.pdb]
# processing [512_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.497 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.041 seconds.
#
# P2Rank Output for 47_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [47_protein.pdb]
# processing [47_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.424 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.911 seconds.
#
# P2Rank Output for 1946_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1946_protein.pdb]
# processing [1946_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.628 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.178 seconds.
#
# P2Rank Output for 2343_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2343_protein.pdb]
# processing [2343_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.315 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.833 seconds.
#
# P2Rank Output for 3001_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [3001_protein.pdb]
# processing [3001_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.514 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.071 seconds.
#
# P2Rank Output for 2613_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2613_protein.pdb]
# processing [2613_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.628 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 5.098 seconds.
#
# P2Rank Output for 400_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [400_protein.pdb]
# processing [400_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.489 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.048 seconds.
#
# P2Rank Output for 150_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [150_protein.pdb]
# processing [150_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.186 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.669 seconds.
#
# P2Rank Output for 1279_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1279_protein.pdb]
# processing [1279_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 5.376 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 5.957 seconds.
#
# P2Rank Output for 1729_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1729_protein.pdb]
# processing [1729_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 5.115 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 5.926 seconds.
#
# P2Rank Output for 826_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [826_protein.pdb]
# processing [826_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 7.159 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 7.919 seconds.
#
# P2Rank Output for 286_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [286_protein.pdb]
# processing [286_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 5.624 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 6.401 seconds.
#
# P2Rank Output for 1560_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1560_protein.pdb]
# processing [1560_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.530 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 5.327 seconds.
#
# P2Rank Output for 2095_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2095_protein.pdb]
# processing [2095_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 5.145 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 5.920 seconds.
#
# P2Rank Output for 1030_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1030_protein.pdb]
# processing [1030_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.068 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.739 seconds.
#
# P2Rank Output for 319_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [319_protein.pdb]
# processing [319_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.604 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 5.234 seconds.
#
# P2Rank Output for 649_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [649_protein.pdb]
# processing [649_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.649 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.236 seconds.
#
# P2Rank Output for 2068_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2068_protein.pdb]
# processing [2068_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.572 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.184 seconds.
#
# P2Rank Output for 2538_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2538_protein.pdb]
# processing [2538_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.227 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.766 seconds.
#
# P2Rank Output for 944_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [944_protein.pdb]
# processing [944_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.852 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.433 seconds.
#
# P2Rank Output for 1152_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1152_protein.pdb]
# processing [1152_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.316 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.861 seconds.
#
# P2Rank Output for 1402_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1402_protein.pdb]
# processing [1402_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.702 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.267 seconds.
#
# P2Rank Output for 2771_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2771_protein.pdb]
# processing [2771_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.721 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.301 seconds.
#
# P2Rank Output for 1284_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1284_protein.pdb]
# processing [1284_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.650 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.200 seconds.
#
# P2Rank Output for 2221_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2221_protein.pdb]
# processing [2221_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.591 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.115 seconds.
#
# P2Rank Output for 1824_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1824_protein.pdb]
# processing [1824_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.791 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.357 seconds.
#
# P2Rank Output for 2881_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2881_protein.pdb]
# processing [2881_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.864 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.440 seconds.
#
# P2Rank Output for 37_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [37_protein.pdb]
# processing [37_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.892 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.463 seconds.
#
# P2Rank Output for 562_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [562_protein.pdb]
# processing [562_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.688 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.237 seconds.
#
# P2Rank Output for 1838_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1838_protein.pdb]
# processing [1838_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.681 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.218 seconds.
#
# P2Rank Output for 1298_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1298_protein.pdb]
# processing [1298_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 6.023 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 6.578 seconds.
#
# P2Rank Output for 2902_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2902_protein.pdb]
# processing [2902_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.606 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.156 seconds.
#
# P2Rank Output for 1657_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1657_protein.pdb]
# processing [1657_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.521 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.034 seconds.
#
# P2Rank Output for 1307_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1307_protein.pdb]
# processing [1307_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.176 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.756 seconds.
#
# P2Rank Output for 2074_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2074_protein.pdb]
# processing [2074_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.405 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.964 seconds.
#
# P2Rank Output for 958_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [958_protein.pdb]
# processing [958_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.038 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.567 seconds.
#
# P2Rank Output for 1581_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1581_protein.pdb]
# processing [1581_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.554 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.093 seconds.
#
# P2Rank Output for 2524_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2524_protein.pdb]
# processing [2524_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.789 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.349 seconds.
#
# P2Rank Output for 737_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [737_protein.pdb]
# processing [737_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.840 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.407 seconds.
#
# P2Rank Output for 267_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [267_protein.pdb]
# processing [267_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.588 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.152 seconds.
#
# P2Rank Output for 2446_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2446_protein.pdb]
# processing [2446_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.741 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.274 seconds.
#
# P2Rank Output for 2116_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2116_protein.pdb]
# processing [2116_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.607 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.142 seconds.
#
# P2Rank Output for 305_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [305_protein.pdb]
# processing [305_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.779 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.334 seconds.
#
# P2Rank Output for 655_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [655_protein.pdb]
# processing [655_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 5.667 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 6.237 seconds.
#
# P2Rank Output for 2089_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2089_protein.pdb]
# processing [2089_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.437 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.942 seconds.
#
# P2Rank Output for 583_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [583_protein.pdb]
# processing [583_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.054 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.622 seconds.
#
# P2Rank Output for 1265_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1265_protein.pdb]
# processing [1265_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.683 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.245 seconds.
#
# P2Rank Output for 2790_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2790_protein.pdb]
# processing [2790_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.616 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.148 seconds.
#
# P2Rank Output for 1735_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1735_protein.pdb]
# processing [1735_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.855 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.416 seconds.
#
# P2Rank Output for 2860_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2860_protein.pdb]
# processing [2860_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.625 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.194 seconds.
#
# P2Rank Output for 491_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [491_protein.pdb]
# processing [491_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.340 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.891 seconds.
#
# P2Rank Output for 1848_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1848_protein.pdb]
# processing [1848_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.612 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.173 seconds.
#
# P2Rank Output for 1627_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1627_protein.pdb]
# processing [1627_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.359 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.904 seconds.
#
# P2Rank Output for 2682_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2682_protein.pdb]
# processing [2682_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.478 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.040 seconds.
#
# P2Rank Output for 1377_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1377_protein.pdb]
# processing [1377_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.539 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.099 seconds.
#
# P2Rank Output for 2972_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2972_protein.pdb]
# processing [2972_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.709 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.230 seconds.
#
# P2Rank Output for 388_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [388_protein.pdb]
# processing [388_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.910 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.474 seconds.
#
# P2Rank Output for 2004_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2004_protein.pdb]
# processing [2004_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.365 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.930 seconds.
#
# P2Rank Output for 2554_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2554_protein.pdb]
# processing [2554_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.475 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.011 seconds.
#
# P2Rank Output for 928_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [928_protein.pdb]
# processing [928_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.390 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.944 seconds.
#
# P2Rank Output for 747_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [747_protein.pdb]
# processing [747_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.074 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.602 seconds.
#
# P2Rank Output for 217_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [217_protein.pdb]
# processing [217_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.446 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.020 seconds.
#
# P2Rank Output for 2436_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2436_protein.pdb]
# processing [2436_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.891 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.452 seconds.
#
# P2Rank Output for 1493_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1493_protein.pdb]
# processing [1493_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.703 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# ...
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2003_protein.pdb]
# processing [2003_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.386 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.923 seconds.
#
# P2Rank Output for 1167_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1167_protein.pdb]
# processing [1167_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.346 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.886 seconds.
#
# P2Rank Output for 1437_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1437_protein.pdb]
# processing [1437_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.329 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.880 seconds.
#
# P2Rank Output for 2492_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2492_protein.pdb]
# processing [2492_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.583 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.152 seconds.
#
# P2Rank Output for 971_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [971_protein.pdb]
# processing [971_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.771 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.312 seconds.
#
# P2Rank Output for 681_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [681_protein.pdb]
# processing [681_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.628 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.155 seconds.
#
# P2Rank Output for 557_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [557_protein.pdb]
# processing [557_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.702 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.228 seconds.
#
# P2Rank Output for 198_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [198_protein.pdb]
# processing [198_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.529 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 5.080 seconds.
#
# P2Rank Output for 1811_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1811_protein.pdb]
# processing [1811_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.237 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.771 seconds.
#
# P2Rank Output for 2744_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2744_protein.pdb]
# processing [2744_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.410 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.945 seconds.
#
# P2Rank Output for 2214_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2214_protein.pdb]
# processing [2214_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.014 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.521 seconds.
#
# P2Rank Output for 2849_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2849_protein.pdb]
# processing [2849_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.691 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.163 seconds.
#
# P2Rank Output for 435_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [435_protein.pdb]
# processing [435_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.779 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.382 seconds.
#
# P2Rank Output for 165_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [165_protein.pdb]
# processing [165_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.757 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 5.292 seconds.
#
# P2Rank Output for 2376_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2376_protein.pdb]
# processing [2376_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.179 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.761 seconds.
#
# P2Rank Output for 2626_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2626_protein.pdb]
# processing [2626_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.321 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.851 seconds.
#
# P2Rank Output for 1683_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1683_protein.pdb]
# processing [1683_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.125 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.672 seconds.
#
# P2Rank Output for 3034_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [3034_protein.pdb]
# processing [3034_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.642 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.190 seconds.
#
# P2Rank Output for 1973_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1973_protein.pdb]
# processing [1973_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.530 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 5.097 seconds.
#
# P2Rank Output for 1555_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1555_protein.pdb]
# processing [1555_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.355 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.829 seconds.
#
# P2Rank Output for 1005_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1005_protein.pdb]
# processing [1005_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.515 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.017 seconds.
#
# P2Rank Output for 813_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [813_protein.pdb]
# processing [813_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.138 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.670 seconds.
#
# P2Rank Output for 1117_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1117_protein.pdb]
# processing [1117_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.924 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.505 seconds.
#
# P2Rank Output for 1447_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1447_protein.pdb]
# processing [1447_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.656 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.152 seconds.
#
# P2Rank Output for 1088_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1088_protein.pdb]
# processing [1088_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.535 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.064 seconds.
#
# P2Rank Output for 901_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [901_protein.pdb]
# processing [901_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.587 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.142 seconds.
#
# P2Rank Output for 72_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [72_protein.pdb]
# processing [72_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.591 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.082 seconds.
#
# P2Rank Output for 527_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [527_protein.pdb]
# processing [527_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.547 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.070 seconds.
#
# P2Rank Output for 1791_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1791_protein.pdb]
# processing [1791_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.487 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.974 seconds.
#
# P2Rank Output for 2734_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2734_protein.pdb]
# processing [2734_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.548 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.080 seconds.
#
# P2Rank Output for 2264_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2264_protein.pdb]
# processing [2264_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.417 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.967 seconds.
#
# P2Rank Output for 1861_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1861_protein.pdb]
# processing [1861_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.613 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.143 seconds.
#
# P2Rank Output for 445_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [445_protein.pdb]
# processing [445_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.577 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.125 seconds.
#
# P2Rank Output for 2839_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2839_protein.pdb]
# processing [2839_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.651 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.147 seconds.
#
# P2Rank Output for 115_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [115_protein.pdb]
# processing [115_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.402 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.978 seconds.
#
# P2Rank Output for 2299_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2299_protein.pdb]
# processing [2299_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.450 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.987 seconds.
#
# P2Rank Output for 1903_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1903_protein.pdb]
# processing [1903_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.599 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.122 seconds.
#
# P2Rank Output for 2306_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2306_protein.pdb]
# processing [2306_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 4.251 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.773 seconds.
#
# P2Rank Output for 3044_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [3044_protein.pdb]
# processing [3044_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.201 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.725 seconds.
#
# P2Rank Output for 2656_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2656_protein.pdb]
# processing [2656_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.386 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.919 seconds.
#
# P2Rank Output for 2580_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [2580_protein.pdb]
# processing [2580_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.594 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.128 seconds.
#
# P2Rank Output for 1525_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1525_protein.pdb]
# processing [1525_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.409 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.896 seconds.
#
# P2Rank Output for 1075_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [1075_protein.pdb]
# processing [1075_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.744 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.334 seconds.
#
# P2Rank Output for 863_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [863_protein.pdb]
# processing [863_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.333 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 3.863 seconds.
#
# P2Rank Output for 793_protein.pdb:
#  P2Rank 2.4.2-beta.1
#
# predicting pockets for proteins from dataset [793_protein.pdb]
# processing [793_protein.pdb] (1/1)
# predicting pockets finished in 0 hours 0 minutes 3.952 seconds
# results saved to directory [/Users/peter/VS_Studio/Bioninformatics/Outputs]
#
# Finished successfully in 0 hours 0 minutes 4.480 seconds.

# %%
# So before I simply retrieved all possible binding pockets.
# this time i will apply a probability threshold to extract the binding pockets 

import os
import pandas as pd

def collect_binding_residues_threshold(output_dir, submission_file, threshold):
    submission_data = []

    for item in os.listdir(output_dir):
        # we only look at files that end with _residues.csv
        if item.endswith('_residues.csv'):
            # we get the id by simply removing the rest of the file name
            pdb_id = item.replace('_protein.pdb_residues.csv', '')
            # then we collect the file path to extract the predicitons
            residues_file_path = os.path.join(output_dir, item)
            df = pd.read_csv(residues_file_path)
            
            # I had to debug some key error because of a missing blank space -.-
            #print(df)
            #print(f"Columns in {residues_file_path}: {df.columns.tolist()}")

            # for proper evaluation we require that predictions are stripped properly
            df.columns = df.columns.str.strip()

            # basically if the residue is part of a binding pocket we add it to our predictions
            #binding_residues = df[df['pocket'] > 0]['residue_label'].tolist()
            filtered_residues = df[(df['pocket'] > 0) & (df['probability'] >= threshold)]
            binding_residues = filtered_residues.apply(lambda row: f" {row['chain']}_{row['residue_label']}", axis=1).tolist()

            prediction = ''.join(binding_residues)
            submission_data.append({'id': pdb_id, 'prediction': prediction})

            # now we convert our submission_data to a csv file and save it with the inputted path
            df_submission = pd.DataFrame(submission_data)
            df_submission['prediction'] = df_submission['prediction'].astype(str) # ensures str which is necessary for evaluation
            # Sort by 'id' column
            # for this we need to convert the ids to integers
            df_submission['id'] = pd.to_numeric(df_submission['id'], errors='coerce')
            df_submission.sort_values(by='id', inplace=True)
            df_submission['id'] = df_submission['id'].astype(str) # reconvert part of debugging
            df_submission.to_csv(submission_file, index=False, sep=',')

# submission_file = "/Users/peter/VS_Studio/Bioninformatics/traintestcsv.csv"
# output_dir = "/Users/peter/VS_Studio/Bioninformatics/Outputs"
# submission_data = collect_binding_residues(output_dir, submission_file)

# %%
submission_file = "/Users/peter/VS_Studio/Bioninformatics/Peter_Schoeberl_Submission.csv"
output_dir = "/Users/peter/VS_Studio/Bioninformatics/Outputs"
submission_data = collect_binding_residues_threshold(output_dir, submission_file, 0.2)

# %%
# So before I simply retrieved all possible binding pockets or applied a threshold
# this time i simply pull out from pdb_predictions the most probable pocket

import os
import pandas as pd
import csv

def extract_first_row_residue_ids(file_path):
    with open(file_path, mode='r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            # Strip spaces from keys and get the 'residue_ids'
            clean_row = {key.strip(): value for key, value in row.items()}
            #print(clean_row)
            # directly return predictions from first most probable pocket
            return clean_row.get('residue_ids', None)
    # if there is no prediction predict none
    return ''

def collect_binding_residues_most_probable(output_dir, submission_file):
    submission_data = []

    for item in os.listdir(output_dir):
        # we only look at files that end with _residues.csv
        if item.endswith('_predictions.csv'):
            # we get the id by simply removing the rest of the file name
            pdb_id = item.replace('_protein.pdb_predictions.csv', '')
            # then we collect the file path to extract the predicitons
            residues_file_path = os.path.join(output_dir, item)
            # and simply return the most probable pocket with its corresponding ids
            prediction = extract_first_row_residue_ids(residues_file_path)
            #print(prediction)
            # then we already add it to our data
            submission_data.append({'id': pdb_id, 'prediction': prediction})

            # now we convert our submission_data to a csv file and save it with the inputted path
            df_submission = pd.DataFrame(submission_data)
            df_submission['prediction'] = df_submission['prediction'].astype(str) # ensures str which is necessary for evaluation
            # Sort by 'id' column
            # for this we need to convert the ids to integers
            df_submission['id'] = pd.to_numeric(df_submission['id'], errors='coerce')
            df_submission.sort_values(by='id', inplace=True)
            df_submission['id'] = df_submission['id'].astype(str) # reconvert part of debugging
            df_submission.to_csv(submission_file, index=False, sep=',')

# submission_file = "/Users/peter/VS_Studio/Bioninformatics/traintestcsv.csv"
# output_dir = "/Users/peter/VS_Studio/Bioninformatics/Outputs"
# submission_data = collect_binding_residues(output_dir, submission_file)

# %%
submission_file = "/Users/peter/VS_Studio/Bioninformatics/Peter_Schoeberl_Submission.csv"
output_dir = "/Users/peter/VS_Studio/Bioninformatics/Outputs"
submission_data = collect_binding_residues_most_probable(output_dir, submission_file)

# %% [markdown]
# # Evaluation
#
# depending on the extraction I approach I got the following results:
#
# - All possible pockets
#
#     =           0.195 score
#
# - Pockets with probability over 0.5
#
# 	=           0.155 score
#
# - Pockets with probability over 0.2
#
# 	=           0.195 score
#
# - The one most probable pocket
#
#     =           **0.261 score**
